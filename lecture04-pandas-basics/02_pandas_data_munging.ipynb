# %% [markdown]
# # Lecture 04 – part II
#
# ## Introduction to Data-munging (Data wrangling)
#
#    - Add new manipulated variables
#    - Separate char to new variables
#    - Convert variables to numeric or factor
#    - Some string manipulations
#    - Rename variables
#    - Filter out different observations
#      - conditional selection
#      - tabulate frequency of a var
#      - missing values
#      - replace values
#      - duplicates
#    - Using pipes
#    - Sorting data
#
# #### Case-study
#
# - Based on: Chapter 02, A:
#     - Finding a good deal among hotels: data preparation
#
# #### Dataset:
# - hotels-europe
# ---

# %%
#Import the libraries
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# Import raw data

# %%
raw_df = pd.read_csv("https://osf.io/yzntm/download")

# %% [markdown]
# Have a look at the data

# %%
raw_df.head()
# Out:
#   addresscountryname city_actual  rating_reviewcount center1distance  \
# 0        Netherlands   Amsterdam              1030.0       3.1 miles
# 1        Netherlands   Amsterdam              1030.0       3.1 miles
# 2        Netherlands   Amsterdam              1030.0       3.1 miles
# 3        Netherlands   Amsterdam              1030.0       3.1 miles
# 4        Netherlands   Amsterdam              1030.0       3.1 miles
#
#   center1label center2distance      center2label neighbourhood  price  \
# 0  City centre       3.6 miles  Montelbaanstoren     Amsterdam    172
# 1  City centre       3.6 miles  Montelbaanstoren     Amsterdam    122
# 2  City centre       3.6 miles  Montelbaanstoren     Amsterdam    122
# 3  City centre       3.6 miles  Montelbaanstoren     Amsterdam    552
# 4  City centre       3.6 miles  Montelbaanstoren     Amsterdam    122
#
#           price_night  ...  accommodationtype  guestreviewsrating  \
# 0   price for 1 night  ...  _ACCOM_TYPE@Hotel              4.3 /5
# 1   price for 1 night  ...  _ACCOM_TYPE@Hotel              4.3 /5
# 2   price for 1 night  ...  _ACCOM_TYPE@Hotel              4.3 /5
# 3  price for 4 nights  ...  _ACCOM_TYPE@Hotel              4.3 /5
# 4   price for 1 night  ...  _ACCOM_TYPE@Hotel              4.3 /5
#
#    scarce_room  hotel_id offer     offer_cat  year  month  weekend holiday
# 0            0       1.0     0   0% no offer  2017     11        1       0
# 1            0       1.0     1  15-50% offer  2018      1        1       0
# 2            0       1.0     1  15-50% offer  2017     12        0       1
# 3            0       1.0     1   1-15% offer  2017     12        0       1
# 4            0       1.0     1  15-50% offer  2018      2        1       0
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 1) Adding a new variable
#
# Let us add nnights variable, which shows the number of nights spent in the hotel\
# As the data was collected in such way, it is 1 for each observations.

# %% [markdown]
# You can assign a new variable using the following syntax

# %%
raw_df["nnights"] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 raw_df["nnights"] = 1
#
# NameError: name 'raw_df' is not defined

# %% [markdown]
# Or use the `assign` function of pandas and also create a new variable, lets call it `df`

# %%
df = raw_df.assign(nnights = 1)

# %% [markdown]
# Lets remove the raw data

# %%
del raw_df

# %%
df.head()
# Out:
#   addresscountryname city_actual  rating_reviewcount center1distance  \
# 0        Netherlands   Amsterdam              1030.0       3.1 miles
# 1        Netherlands   Amsterdam              1030.0       3.1 miles
# 2        Netherlands   Amsterdam              1030.0       3.1 miles
# 3        Netherlands   Amsterdam              1030.0       3.1 miles
# 4        Netherlands   Amsterdam              1030.0       3.1 miles
#
#   center1label center2distance      center2label neighbourhood  price  \
# 0  City centre       3.6 miles  Montelbaanstoren     Amsterdam    172
# 1  City centre       3.6 miles  Montelbaanstoren     Amsterdam    122
# 2  City centre       3.6 miles  Montelbaanstoren     Amsterdam    122
# 3  City centre       3.6 miles  Montelbaanstoren     Amsterdam    552
# 4  City centre       3.6 miles  Montelbaanstoren     Amsterdam    122
#
#           price_night  ... scarce_room  hotel_id  offer     offer_cat  year  \
# 0   price for 1 night  ...           0       1.0      0   0% no offer  2017
# 1   price for 1 night  ...           0       1.0      1  15-50% offer  2018
# 2   price for 1 night  ...           0       1.0      1  15-50% offer  2017
# 3  price for 4 nights  ...           0       1.0      1   1-15% offer  2017
# 4   price for 1 night  ...           0       1.0      1  15-50% offer  2018
#
#   month  weekend  holiday  nnights acc_type
# 0    11        1        0        1    Hotel
# 1     1        1        0        1    Hotel
# 2    12        0        1        1    Hotel
# 3    12        0        1        1    Hotel
# 4     2        1        0        1    Hotel
#
# [5 rows x 26 columns]

# %% [markdown]
# ### 2) Data cleaning - selecting a variable

# %% [markdown]
# You can select variables with `[]` brackets after the DataFrame object

# %%
df[["accommodationtype" , "price"]]
# Out:
#         accommodationtype  price
# 0       _ACCOM_TYPE@Hotel    172
# 1       _ACCOM_TYPE@Hotel    122
# 2       _ACCOM_TYPE@Hotel    122
# 3       _ACCOM_TYPE@Hotel    552
# 4       _ACCOM_TYPE@Hotel    122
# ...                   ...    ...
# 149961  _ACCOM_TYPE@Hotel    119
# 149962  _ACCOM_TYPE@Hotel    109
# 149963  _ACCOM_TYPE@Hotel    109
# 149964  _ACCOM_TYPE@Hotel    446
# 149965  _ACCOM_TYPE@Hotel    117
#
# [149966 rows x 2 columns]

# %% [markdown]
# Or use the `filter` function

# %%
df.filter(["accommodationtype" , "price"])
# Out:
#         accommodationtype  price
# 0       _ACCOM_TYPE@Hotel    172
# 1       _ACCOM_TYPE@Hotel    122
# 2       _ACCOM_TYPE@Hotel    122
# 3       _ACCOM_TYPE@Hotel    552
# 4       _ACCOM_TYPE@Hotel    122
# ...                   ...    ...
# 149961  _ACCOM_TYPE@Hotel    119
# 149962  _ACCOM_TYPE@Hotel    109
# 149963  _ACCOM_TYPE@Hotel    109
# 149964  _ACCOM_TYPE@Hotel    446
# 149965  _ACCOM_TYPE@Hotel    117
#
# [149966 rows x 2 columns]

# %% [markdown]
# You can also select columns with `filter` using Regular Expressions aka regex

# %%
df.filter(regex="rating")
# Out:
#         rating_reviewcount  starrating  rating2_ta  rating2_ta_reviewcount  \
# 0                   1030.0         4.0         4.0                  1115.0
# 1                   1030.0         4.0         4.0                  1115.0
# 2                   1030.0         4.0         4.0                  1115.0
# 3                   1030.0         4.0         4.0                  1115.0
# 4                   1030.0         4.0         4.0                  1115.0
# ...                    ...         ...         ...                     ...
# 149961                48.0         4.0         4.5                    86.0
# 149962                48.0         4.0         4.5                    86.0
# 149963                48.0         4.0         4.5                    86.0
# 149964                48.0         4.0         4.5                    86.0
# 149965                48.0         4.0         4.5                    86.0
#
#        guestreviewsrating
# 0                  4.3 /5
# 1                  4.3 /5
# 2                  4.3 /5
# 3                  4.3 /5
# 4                  4.3 /5
# ...                   ...
# 149961             4.5 /5
# 149962             4.5 /5
# 149963             4.5 /5
# 149964             4.5 /5
# 149965             4.5 /5
#
# [149966 rows x 5 columns]

# %% [markdown]
# ### 3) separating character vector with a unique sign

# %% [markdown]
#  Check accomotationtype: it is a character with a clear separator "@"
#
#  To clean accommodationtype column: separate the characters at @
#    and create two new variables: "garbage" and "acc_type".
#  garbage will contain all characters before @ sign and acc_type will take everything after!

# %%
df["accommodationtype"]
# Out:
# 0         _ACCOM_TYPE@Hotel
# 1         _ACCOM_TYPE@Hotel
# 2         _ACCOM_TYPE@Hotel
# 3         _ACCOM_TYPE@Hotel
# 4         _ACCOM_TYPE@Hotel
#                 ...
# 149961    _ACCOM_TYPE@Hotel
# 149962    _ACCOM_TYPE@Hotel
# 149963    _ACCOM_TYPE@Hotel
# 149964    _ACCOM_TYPE@Hotel
# 149965    _ACCOM_TYPE@Hotel
# Name: accommodationtype, Length: 149966, dtype: object

# %% [markdown]
# You can easily split and strip character columns with pandas with attaching the `str` function after column name

# %%
df["accommodationtype"].str.split("@")
# Out:
# 0         [_ACCOM_TYPE, Hotel]
# 1         [_ACCOM_TYPE, Hotel]
# 2         [_ACCOM_TYPE, Hotel]
# 3         [_ACCOM_TYPE, Hotel]
# 4         [_ACCOM_TYPE, Hotel]
#                   ...
# 149961    [_ACCOM_TYPE, Hotel]
# 149962    [_ACCOM_TYPE, Hotel]
# 149963    [_ACCOM_TYPE, Hotel]
# 149964    [_ACCOM_TYPE, Hotel]
# 149965    [_ACCOM_TYPE, Hotel]
# Name: accommodationtype, Length: 149966, dtype: object

# %% [markdown]
# This results in a Series of lists, each list contains the splitted parts of the original string. You can access the with the following syntax

# %%
df["accommodationtype"].str.split("@").str[0]
# Out:
# 0         _ACCOM_TYPE
# 1         _ACCOM_TYPE
# 2         _ACCOM_TYPE
# 3         _ACCOM_TYPE
# 4         _ACCOM_TYPE
#              ...
# 149961    _ACCOM_TYPE
# 149962    _ACCOM_TYPE
# 149963    _ACCOM_TYPE
# 149964    _ACCOM_TYPE
# 149965    _ACCOM_TYPE
# Name: accommodationtype, Length: 149966, dtype: object

# %%
df["accommodationtype"].str.split("@").str[1].str.strip()
# Out:
# 0         Hotel
# 1         Hotel
# 2         Hotel
# 3         Hotel
# 4         Hotel
#           ...
# 149961    Hotel
# 149962    Hotel
# 149963    Hotel
# 149964    Hotel
# 149965    Hotel
# Name: accommodationtype, Length: 149966, dtype: object

# %% [markdown]
# The second value in the lists contains the type of information about the accomodation type, lets create a new variable out of it.

# %%
df["acc_type"] = df["accommodationtype"].str.split("@").str[1].str.strip()
df["acc_type"].value_counts()
# Out:
# acc_type
# Hotel                  102234
# Apartment               17113
# Guest House             10080
# Bed and breakfast        6395
# Hostel                   6232
# Apart-hotel              3693
# Vacation home Condo      1576
# Pension                  1085
# Inn                      1020
# Country House              89
# Palace                     68
#                            65
# Villa                      64
# Resort                     60
# Caravan Park               60
# House boat                 31
# Pousada                    28
# Motel                      25
# Cabin / Lodge              14
# Cottage                    13
# Chalet                     11
# Castle                      5
# All inclusive               5
# Name: count, dtype: int64

# %% [markdown]
# Its a good idea to use the `strip` function when splitting string variables as it removes any unnecessary white space

# %% [markdown]
# ### Task - creating a numeric vector w simple separation
#
#   1) Correct the `guestreviewsrating` variable into simple numeric variable\
#   2) Check with `.dtypes` method\
#   3) Convert the variable into a numeric variable

# %%
df["guestreviewsrating"].value_counts(dropna=False)
# Out:
# guestreviewsrating
# 4 /5      23160
# 3.7 /5    15031
# 4.5 /5    14952
# 4.3 /5    11268
# 4.1 /5    11190
# 3.5 /5    11145
# NaN       10587
# 4.4 /5     9079
# 3.9 /5     8853
# 3.2 /5     6112
# 3 /5       4838
# 4.6 /5     4417
# 3.4 /5     3727
# 4.8 /5     3095
# 5 /5       2646
# 2.7 /5     2337
# 2.5 /5     1557
# 2.9 /5     1213
# 4.9 /5     1157
# 2 /5        976
# 2.2 /5      976
# 1 /5        679
# 2.4 /5      472
# 1.7 /5      143
# 1.8 /5      112
# 1.5 /5       91
# 1.6 /5       54
# 1.2 /5       48
# 1.3 /5       41
# 1.1 /5       10
# Name: count, dtype: int64

# %%
df["ratings"] = df["guestreviewsrating"].str.split('/').str[0].str.strip()
df["ratings"].dtypes
# Out:
# dtype('O')

# %%
df["ratings"] = df["ratings"].astype(float)

# %%
df["ratings"].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### Task
#
# Create numerical variables from the two distance measures:

# %%
df[["center1distance", "center2distance"]]
# Out:
#        center1distance center2distance
# 0            3.1 miles       3.6 miles
# 1            3.1 miles       3.6 miles
# 2            3.1 miles       3.6 miles
# 3            3.1 miles       3.6 miles
# 4            3.1 miles       3.6 miles
# ...                ...             ...
# 149961       1.1 miles       0.6 miles
# 149962       1.1 miles       0.6 miles
# 149963       1.1 miles       0.6 miles
# 149964       1.1 miles       0.6 miles
# 149965       1.1 miles       0.6 miles
#
# [149966 rows x 2 columns]

# %% [markdown]
# We have two numeric values than the format of the distance "miles"

# %%
df["distance"] = df["center1distance"].str.strip().str.split().str[0].astype(float)
df["distance_alter"] = df["center2distance"].str.strip().str.split().str[0].astype(float)

# %% [markdown]
# Check results

# %%
df["distance"].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# ### Rename variables

# %% [markdown]
# Using the `rename` function, you have to specify in a dictionary that which columns you want to rename and their new names

# %%
df.filter(regex="rating")
# Out:
#         rating_reviewcount  starrating  rating2_ta  rating2_ta_reviewcount  \
# 0                   1030.0         4.0         4.0                  1115.0
# 1                   1030.0         4.0         4.0                  1115.0
# 2                   1030.0         4.0         4.0                  1115.0
# 3                   1030.0         4.0         4.0                  1115.0
# 4                   1030.0         4.0         4.0                  1115.0
# ...                    ...         ...         ...                     ...
# 149961                48.0         4.0         4.5                    86.0
# 149962                48.0         4.0         4.5                    86.0
# 149963                48.0         4.0         4.5                    86.0
# 149964                48.0         4.0         4.5                    86.0
# 149965                48.0         4.0         4.5                    86.0
#
#        guestreviewsrating  ratings
# 0                  4.3 /5      4.3
# 1                  4.3 /5      4.3
# 2                  4.3 /5      4.3
# 3                  4.3 /5      4.3
# 4                  4.3 /5      4.3
# ...                   ...      ...
# 149961             4.5 /5      4.5
# 149962             4.5 /5      4.5
# 149963             4.5 /5      4.5
# 149964             4.5 /5      4.5
# 149965             4.5 /5      4.5
#
# [149966 rows x 6 columns]

# %%
df = df.rename(columns={"rating_reviewcount": "rating_count", "rating2_ta": "ratingta"})

# %%
df.filter(regex="rating")
# Out:
#         rating_reviewcount  starrating  rating2_ta  rating2_ta_reviewcount  \
# 0                   1030.0         4.0         4.0                  1115.0
# 1                   1030.0         4.0         4.0                  1115.0
# 2                   1030.0         4.0         4.0                  1115.0
# 3                   1030.0         4.0         4.0                  1115.0
# 4                   1030.0         4.0         4.0                  1115.0
# ...                    ...         ...         ...                     ...
# 149961                48.0         4.0         4.5                    86.0
# 149962                48.0         4.0         4.5                    86.0
# 149963                48.0         4.0         4.5                    86.0
# 149964                48.0         4.0         4.5                    86.0
# 149965                48.0         4.0         4.5                    86.0
#
#        guestreviewsrating  ratings
# 0                  4.3 /5      4.3
# 1                  4.3 /5      4.3
# 2                  4.3 /5      4.3
# 3                  4.3 /5      4.3
# 4                  4.3 /5      4.3
# ...                   ...      ...
# 149961             4.5 /5      4.5
# 149962             4.5 /5      4.5
# 149963             4.5 /5      4.5
# 149964             4.5 /5      4.5
# 149965             4.5 /5      4.5
#
# [149966 rows x 6 columns]

# %% [markdown]
# ### Task:
#
# also rename the following variables as follows:
#
#     rating2_ta_reviewcount: ratingta_count
#     addresscountryname: "country
#     starrating: stars
#     s_city": city

# %%
df = df.rename(columns={
    "rating2_ta_reviewcount": "ratingta_count",
    "addresscountryname": "country",
    "starrating": "stars",
    "s_city": "city",
})

# %% [markdown]
# ### Filtering observations

# %% [markdown]
# Use the `loc` function

# %%
df.shape
# Out:
# (149966, 29)

# %% [markdown]
# let us have only hotels

# %%
df.loc[df["acc_type"] == "Hotel"]
# Out:
#             country city_actual  rating_reviewcount center1distance  \
# 0       Netherlands   Amsterdam              1030.0       3.1 miles
# 1       Netherlands   Amsterdam              1030.0       3.1 miles
# 2       Netherlands   Amsterdam              1030.0       3.1 miles
# 3       Netherlands   Amsterdam              1030.0       3.1 miles
# 4       Netherlands   Amsterdam              1030.0       3.1 miles
# ...             ...         ...                 ...             ...
# 149961      Croatia      Zagreb                48.0       1.1 miles
# 149962      Croatia      Zagreb                48.0       1.1 miles
# 149963      Croatia      Zagreb                48.0       1.1 miles
# 149964      Croatia      Zagreb                48.0       1.1 miles
# 149965      Croatia      Zagreb                48.0       1.1 miles
#
#        center1label center2distance        center2label neighbourhood  price  \
# 0       City centre       3.6 miles    Montelbaanstoren     Amsterdam    172
# 1       City centre       3.6 miles    Montelbaanstoren     Amsterdam    122
# 2       City centre       3.6 miles    Montelbaanstoren     Amsterdam    122
# 3       City centre       3.6 miles    Montelbaanstoren     Amsterdam    552
# 4       City centre       3.6 miles    Montelbaanstoren     Amsterdam    122
# ...             ...             ...                 ...           ...    ...
# 149961  City centre       0.6 miles  Zagreb City Museum        Zagreb    119
# 149962  City centre       0.6 miles  Zagreb City Museum        Zagreb    109
# 149963  City centre       0.6 miles  Zagreb City Museum        Zagreb    109
# 149964  City centre       0.6 miles  Zagreb City Museum        Zagreb    446
# 149965  City centre       0.6 miles  Zagreb City Museum        Zagreb    117
#
#                price_night  ...     offer_cat  year  month  weekend holiday  \
# 0        price for 1 night  ...   0% no offer  2017     11        1       0
# 1        price for 1 night  ...  15-50% offer  2018      1        1       0
# 2        price for 1 night  ...  15-50% offer  2017     12        0       1
# 3       price for 4 nights  ...   1-15% offer  2017     12        0       1
# 4        price for 1 night  ...  15-50% offer  2018      2        1       0
# ...                    ...  ...           ...   ...    ...      ...     ...
# 149961   price for 1 night  ...  15-50% offer  2017     11        0       0
# 149962   price for 1 night  ...  15-50% offer  2018      4        1       0
# 149963   price for 1 night  ...  15-50% offer  2018      3        1       0
# 149964  price for 4 nights  ...  15-50% offer  2017     12        0       1
# 149965   price for 1 night  ...  15-50% offer  2017     12        0       1
#
#        nnights  acc_type  ratings  distance distance_alter
# 0            1     Hotel      4.3       3.1            3.6
# 1            1     Hotel      4.3       3.1            3.6
# 2            1     Hotel      4.3       3.1            3.6
# 3            1     Hotel      4.3       3.1            3.6
# 4            1     Hotel      4.3       3.1            3.6
# ...        ...       ...      ...       ...            ...
# 149961       1     Hotel      4.5       1.1            0.6
# 149962       1     Hotel      4.5       1.1            0.6
# 149963       1     Hotel      4.5       1.1            0.6
# 149964       1     Hotel      4.5       1.1            0.6
# 149965       1     Hotel      4.5       1.1            0.6
#
# [102234 rows x 29 columns]

# %% [markdown]
# Filtering: find missing values\
# look at one of our key variable: ratings\
# we can calculate the frequencies of the ratings

# %%
df["ratings"].isnull().sum()
# Out:
# 10587

# %% [markdown]
# What can we do with the NA values?\
# First check them with 'loc'

# %%
df.loc[df["ratings"].isnull()]
# Out:
#             country city_actual  rating_reviewcount center1distance  \
# 414     Netherlands   Amsterdam                 NaN       2.4 miles
# 415     Netherlands   Amsterdam                 NaN       2.4 miles
# 416     Netherlands   Amsterdam                 NaN       2.4 miles
# 542     Netherlands   Amsterdam                 NaN       4.7 miles
# 1059    Netherlands   Amsterdam                 NaN       0.7 miles
# ...             ...         ...                 ...             ...
# 149947      Croatia      Zagreb                 NaN       4.0 miles
# 149948      Croatia      Zagreb                 NaN       4.0 miles
# 149949      Croatia      Zagreb                 NaN       4.0 miles
# 149950      Croatia      Zagreb                 NaN       4.0 miles
# 149951      Croatia      Zagreb                 NaN       4.0 miles
#
#        center1label center2distance        center2label  \
# 414     City centre       3.0 miles    Montelbaanstoren
# 415     City centre       3.0 miles    Montelbaanstoren
# 416     City centre       3.0 miles    Montelbaanstoren
# 542     City centre       5.1 miles    Montelbaanstoren
# 1059    City centre       0.2 miles    Montelbaanstoren
# ...             ...             ...                 ...
# 149947  City centre       4.0 miles  Zagreb City Museum
# 149948  City centre       4.0 miles  Zagreb City Museum
# 149949  City centre       4.0 miles  Zagreb City Museum
# 149950  City centre       4.0 miles  Zagreb City Museum
# 149951  City centre       4.0 miles  Zagreb City Museum
#
#                        neighbourhood  price         price_night  ...  \
# 414                   Amsterdam West    175   price for 1 night  ...
# 415                   Amsterdam West    221   price for 1 night  ...
# 416                   Amsterdam West    249   price for 1 night  ...
# 542                   Amsterdam West   1496  price for 4 nights  ...
# 1059    Dam Square - Central Station    232   price for 1 night  ...
# ...                              ...    ...                 ...  ...
# 149947                        Zagreb     77   price for 1 night  ...
# 149948                        Zagreb    311  price for 4 nights  ...
# 149949                        Zagreb     77   price for 1 night  ...
# 149950                        Zagreb     77   price for 1 night  ...
# 149951                        Zagreb     77   price for 1 night  ...
#
#            offer_cat  year  month  weekend holiday nnights   acc_type  \
# 414     15-50% offer  2018      6        1       0       1      Hotel
# 415     15-50% offer  2018      2        1       0       1      Hotel
# 416     15-50% offer  2018      4        1       0       1      Hotel
# 542      0% no offer  2017     12        0       1       1  Apartment
# 1059     0% no offer  2018      6        1       0       1      Hotel
# ...              ...   ...    ...      ...     ...     ...        ...
# 149947   0% no offer  2018      5        1       0       1  Apartment
# 149948   0% no offer  2017     12        0       1       1  Apartment
# 149949   0% no offer  2017     12        0       1       1  Apartment
# 149950   0% no offer  2017     11        0       0       1  Apartment
# 149951   0% no offer  2018      4        1       0       1  Apartment
#
#         ratings  distance distance_alter
# 414         NaN       2.4            3.0
# 415         NaN       2.4            3.0
# 416         NaN       2.4            3.0
# 542         NaN       4.7            5.1
# 1059        NaN       0.7            0.2
# ...         ...       ...            ...
# 149947      NaN       4.0            4.0
# 149948      NaN       4.0            4.0
# 149949      NaN       4.0            4.0
# 149950      NaN       4.0            4.0
# 149951      NaN       4.0            4.0
#
# [10587 rows x 29 columns]

# %% [markdown]
# if reasonable we can drop them, but there needs to be good reason for that!

# %%
df = df.loc[df["ratings"].notnull()]

# %% [markdown]
# Or alternatively ose `dropna`

# %%
df = df.dropna(subset=["ratings"])

# %%
df
# Out:
#             country city_actual  rating_reviewcount center1distance  \
# 0       Netherlands   Amsterdam              1030.0       3.1 miles
# 1       Netherlands   Amsterdam              1030.0       3.1 miles
# 2       Netherlands   Amsterdam              1030.0       3.1 miles
# 3       Netherlands   Amsterdam              1030.0       3.1 miles
# 4       Netherlands   Amsterdam              1030.0       3.1 miles
# ...             ...         ...                 ...             ...
# 149961      Croatia      Zagreb                48.0       1.1 miles
# 149962      Croatia      Zagreb                48.0       1.1 miles
# 149963      Croatia      Zagreb                48.0       1.1 miles
# 149964      Croatia      Zagreb                48.0       1.1 miles
# 149965      Croatia      Zagreb                48.0       1.1 miles
#
#        center1label center2distance        center2label neighbourhood  price  \
# 0       City centre       3.6 miles    Montelbaanstoren     Amsterdam    172
# 1       City centre       3.6 miles    Montelbaanstoren     Amsterdam    122
# 2       City centre       3.6 miles    Montelbaanstoren     Amsterdam    122
# 3       City centre       3.6 miles    Montelbaanstoren     Amsterdam    552
# 4       City centre       3.6 miles    Montelbaanstoren     Amsterdam    122
# ...             ...             ...                 ...           ...    ...
# 149961  City centre       0.6 miles  Zagreb City Museum        Zagreb    119
# 149962  City centre       0.6 miles  Zagreb City Museum        Zagreb    109
# 149963  City centre       0.6 miles  Zagreb City Museum        Zagreb    109
# 149964  City centre       0.6 miles  Zagreb City Museum        Zagreb    446
# 149965  City centre       0.6 miles  Zagreb City Museum        Zagreb    117
#
#                price_night  ...     offer_cat  year  month  weekend holiday  \
# 0        price for 1 night  ...   0% no offer  2017     11        1       0
# 1        price for 1 night  ...  15-50% offer  2018      1        1       0
# 2        price for 1 night  ...  15-50% offer  2017     12        0       1
# 3       price for 4 nights  ...   1-15% offer  2017     12        0       1
# 4        price for 1 night  ...  15-50% offer  2018      2        1       0
# ...                    ...  ...           ...   ...    ...      ...     ...
# 149961   price for 1 night  ...  15-50% offer  2017     11        0       0
# 149962   price for 1 night  ...  15-50% offer  2018      4        1       0
# 149963   price for 1 night  ...  15-50% offer  2018      3        1       0
# 149964  price for 4 nights  ...  15-50% offer  2017     12        0       1
# 149965   price for 1 night  ...  15-50% offer  2017     12        0       1
#
#        nnights  acc_type  ratings  distance distance_alter
# 0            1     Hotel      4.3       3.1            3.6
# 1            1     Hotel      4.3       3.1            3.6
# 2            1     Hotel      4.3       3.1            3.6
# 3            1     Hotel      4.3       3.1            3.6
# 4            1     Hotel      4.3       3.1            3.6
# ...        ...       ...      ...       ...            ...
# 149961       1     Hotel      4.5       1.1            0.6
# 149962       1     Hotel      4.5       1.1            0.6
# 149963       1     Hotel      4.5       1.1            0.6
# 149964       1     Hotel      4.5       1.1            0.6
# 149965       1     Hotel      4.5       1.1            0.6
#
# [139379 rows x 29 columns]

# %% [markdown]
# ### Correcting wrongly documented observations:
#  In case of `stars` there are only values from 0-5

# %%
df["stars"].value_counts(dropna=False)
# Out:
# stars
# 3.0    41692
# 4.0    38583
# 0.0    22451
# 2.0    13360
# 5.0     8346
# 3.5     7797
# 2.5     2940
# 1.0     2383
# 4.5     1661
# 1.5      166
# Name: count, dtype: int64

# %% [markdown]
# What does 0 star means? It is missing, but recorded as 0...\
# We need to set these values to `None`: re-define the stars variable:

# %%
df["stars"] = np.where(df["stars"] == 0, None, df["stars"])

# %%
df["stars"].value_counts(dropna=False)
# Out:
# stars
# 3.0     41692
# 4.0     38583
# None    22451
# 2.0     13360
# 5.0      8346
# 3.5      7797
# 2.5      2940
# 1.0      2383
# 4.5      1661
# 1.5       166
# Name: count, dtype: int64

# %% [markdown]
# ### Duplicates:
#
# 1.) exact match for each values for a given observations\
#
# Count the number of duplicates

# %%
df.duplicated().sum()
# Out:
# 1761

# %% [markdown]
# Remove them

# %%
df = df.drop_duplicates()

# %% [markdown]
# 2.) Remove duplicates to specific variables, that are important to us
#
# To make sense, let us take this into two steps:
#
#     a) select certain variables:

# %%
important_variables = [
    "country",
    "hotel_id",
    "distance",
    "stars",
    "ratings",
    "price",
    "year",
    "month",
    "weekend",
    "holiday",
]

# %% [markdown]
#  Now we can filter out only duplicates in these variables:

# %%
df = df.drop_duplicates(subset=important_variables)

# %% [markdown]
# ### Task: Get specific data used in DA1 course:
#        1) Get hotels only from Vienna
#        2) Filter out the following observations:
#            - in date: 2017, November and 0s week (multiple conditions)
#            - with Hotel types which has stars between 3 and 4
#            - and drop observations which has price more than 1000 EUR.

# %%
hotel_vienna = df.loc[df["city"] == "Vienna"]
hotel_vienna = hotel_vienna.loc[
    (hotel_vienna["year"] == 2017)
    & (hotel_vienna["month"] == 11)
    & (hotel_vienna["weekend"] == 0)
]  # use | and & for bitwise operations
hotel_vienna = hotel_vienna.loc[hotel_vienna["acc_type"] == "Hotel"]
hotel_vienna = hotel_vienna.loc[
    (hotel_vienna["stars"] >= 3) & (hotel_vienna["stars"] <= 4)
]
hotel_vienna = hotel_vienna.loc[hotel_vienna["price"] < 1000]

# %%
hotel_vienna
# Out:
#         country city_actual  rating_count center1distance center1label  \
# 142356  Austria      Vienna         189.0       1.7 miles  City centre
# 142378  Austria      Vienna          53.0       1.4 miles  City centre
# 142388  Austria      Vienna          55.0       1.7 miles  City centre
# 142398  Austria      Vienna          33.0       1.2 miles  City centre
# 142411  Austria      Vienna          57.0       0.9 miles  City centre
# ...         ...         ...           ...             ...          ...
# 145956  Austria      Vienna          77.0       1.2 miles  City centre
# 145965  Austria      Vienna         572.0       1.5 miles  City centre
# 145970  Austria      Vienna          53.0       1.5 miles  City centre
# 146003  Austria      Vienna         112.0        1.0 mile  City centre
# 146010  Austria      Vienna         169.0       1.4 miles  City centre
#
#        center2distance center2label neighbourhood  price        price_night  \
# 142356       3.8 miles    Donauturm   17. Hernals     81  price for 1 night
# 142378       2.5 miles    Donauturm    Alsergrund     85  price for 1 night
# 142388       2.5 miles    Donauturm    Alsergrund     83  price for 1 night
# 142398       2.8 miles    Donauturm    Alsergrund     82  price for 1 night
# 142411       2.4 miles    Donauturm    Alsergrund    103  price for 1 night
# ...                ...          ...           ...    ...                ...
# 145956       3.7 miles    Donauturm        Wieden    100  price for 1 night
# 145965       3.9 miles    Donauturm        Wieden     95  price for 1 night
# 145970       4.0 miles    Donauturm        Wieden     73  price for 1 night
# 146003       3.7 miles    Donauturm        Wieden    100  price for 1 night
# 146010       4.1 miles    Donauturm        Wieden     58  price for 1 night
#
#         ...     offer_cat  year  month  weekend holiday nnights  acc_type  \
# 142356  ...   1-15% offer  2017     11        0       0       1     Hotel
# 142378  ...  15-50% offer  2017     11        0       0       1     Hotel
# 142388  ...  15-50% offer  2017     11        0       0       1     Hotel
# 142398  ...  15-50% offer  2017     11        0       0       1     Hotel
# 142411  ...   0% no offer  2017     11        0       0       1     Hotel
# ...     ...           ...   ...    ...      ...     ...     ...       ...
# 145956  ...   1-15% offer  2017     11        0       0       1     Hotel
# 145965  ...   1-15% offer  2017     11        0       0       1     Hotel
# 145970  ...   1-15% offer  2017     11        0       0       1     Hotel
# 146003  ...   0% no offer  2017     11        0       0       1     Hotel
# 146010  ...  15-50% offer  2017     11        0       0       1     Hotel
#
#         ratings  distance distance_alter
# 142356      3.9       1.7            3.8
# 142378      3.7       1.4            2.5
# 142388      4.0       1.7            2.5
# 142398      3.9       1.2            2.8
# 142411      3.9       0.9            2.4
# ...         ...       ...            ...
# 145956      4.0       1.2            3.7
# 145965      4.1       1.5            3.9
# 145970      3.4       1.5            4.0
# 146003      4.4       1.0            3.7
# 146010      3.2       1.4            4.1
#
# [217 rows x 29 columns]

# %% [markdown]
# ### Pipes with pandas

# %% [markdown]
# You can also do the above procedure in a pipe, which allows to make multiple sequential manipulations with one command:

# %%
(
    df.loc[df["city"] == "Vienna"]
    .loc[(df["year"] == 2017) & (df["month"] == 11) & (df["weekend"] == 0)]
    .loc[df["acc_type"] == "Hotel"]
    .loc[(df["stars"] >= 3) & (df["stars"] <= 4)]
    .loc[df["price"] < 1000]
)
# Out:
#         country city_actual  rating_reviewcount center1distance center1label  \
# 142356  Austria      Vienna               189.0       1.7 miles  City centre
# 142378  Austria      Vienna                53.0       1.4 miles  City centre
# 142388  Austria      Vienna                55.0       1.7 miles  City centre
# 142398  Austria      Vienna                33.0       1.2 miles  City centre
# 142411  Austria      Vienna                57.0       0.9 miles  City centre
# ...         ...         ...                 ...             ...          ...
# 145956  Austria      Vienna                77.0       1.2 miles  City centre
# 145965  Austria      Vienna               572.0       1.5 miles  City centre
# 145970  Austria      Vienna                53.0       1.5 miles  City centre
# 146003  Austria      Vienna               112.0        1.0 mile  City centre
# 146010  Austria      Vienna               169.0       1.4 miles  City centre
#
#        center2distance center2label neighbourhood  price        price_night  \
# 142356       3.8 miles    Donauturm   17. Hernals     81  price for 1 night
# 142378       2.5 miles    Donauturm    Alsergrund     85  price for 1 night
# 142388       2.5 miles    Donauturm    Alsergrund     83  price for 1 night
# 142398       2.8 miles    Donauturm    Alsergrund     82  price for 1 night
# 142411       2.4 miles    Donauturm    Alsergrund    103  price for 1 night
# ...                ...          ...           ...    ...                ...
# 145956       3.7 miles    Donauturm        Wieden    100  price for 1 night
# 145965       3.9 miles    Donauturm        Wieden     95  price for 1 night
# 145970       4.0 miles    Donauturm        Wieden     73  price for 1 night
# 146003       3.7 miles    Donauturm        Wieden    100  price for 1 night
# 146010       4.1 miles    Donauturm        Wieden     58  price for 1 night
#
#         ...     offer_cat  year  month  weekend holiday nnights  acc_type  \
# 142356  ...   1-15% offer  2017     11        0       0       1     Hotel
# 142378  ...  15-50% offer  2017     11        0       0       1     Hotel
# 142388  ...  15-50% offer  2017     11        0       0       1     Hotel
# 142398  ...  15-50% offer  2017     11        0       0       1     Hotel
# 142411  ...   0% no offer  2017     11        0       0       1     Hotel
# ...     ...           ...   ...    ...      ...     ...     ...       ...
# 145956  ...   1-15% offer  2017     11        0       0       1     Hotel
# 145965  ...   1-15% offer  2017     11        0       0       1     Hotel
# 145970  ...   1-15% offer  2017     11        0       0       1     Hotel
# 146003  ...   0% no offer  2017     11        0       0       1     Hotel
# 146010  ...  15-50% offer  2017     11        0       0       1     Hotel
#
#         ratings  distance distance_alter
# 142356      3.9       1.7            3.8
# 142378      3.7       1.4            2.5
# 142388      4.0       1.7            2.5
# 142398      3.9       1.2            2.8
# 142411      3.9       0.9            2.4
# ...         ...       ...            ...
# 145956      4.0       1.2            3.7
# 145965      4.1       1.5            3.9
# 145970      3.4       1.5            4.0
# 146003      4.4       1.0            3.7
# 146010      3.2       1.4            4.1
#
# [217 rows x 29 columns]

# %% [markdown]
# with pipeing, you can lace several different functions in one pipe, eg.

# %%
(
    df.loc[(df["year"] == 2017) & (df["month"] == 11) & (df["weekend"] == 0)]
    .rename(columns={"city": "town"})
    .filter(["hotel_id", "country", "town", "price", "acc_type"])
    .groupby("town")
    .agg(n_hotels=("hotel_id", "nunique"), mean_price=("price", "mean"))
    .sort_values(by=["mean_price"], ascending=False)
    .head(10)
)
# Out:
#             n_hotels  mean_price
# town
# London          1087  195.819687
# Paris           1689  186.979870
# Stockholm        207  186.251208
# Copenhagen       106  180.245283
# Helsinki          84  170.178571
# Valetta           19  161.315789
# Amsterdam        375  154.882667
# Brussels         269  149.271375
# Lyon             147  142.224490
# Munich           318  140.380503

# %% [markdown]
# Make data table more "pretty"
#
# Can arrange the values in increasing order

# %%
hotel_vienna.sort_values(by=["price"], ascending=True)
# Out:
#         country city_actual  rating_count center1distance center1label  \
# 145548  Austria      Vienna          50.0       3.9 miles  City centre
# 145028  Austria      Vienna          69.0       3.1 miles  City centre
# 143663  Austria      Vienna          63.0       1.1 miles  City centre
# 142633  Austria      Vienna         194.0       2.0 miles  City centre
# 145275  Austria      Vienna          79.0       3.7 miles  City centre
# ...         ...         ...           ...             ...          ...
# 142915  Austria      Vienna          81.0       0.3 miles  City centre
# 143484  Austria      Vienna         123.0       0.5 miles  City centre
# 143339  Austria      Vienna          56.0       0.1 miles  City centre
# 143467  Austria      Vienna         404.0       0.0 miles  City centre
# 144499  Austria      Vienna         122.0       1.9 miles  City centre
#
#        center2distance center2label neighbourhood  price        price_night  \
# 145548       6.6 miles    Donauturm        Vienna     50  price for 1 night
# 145028       5.2 miles    Donauturm     Ottakring     52  price for 1 night
# 143663       3.4 miles    Donauturm    Josefstadt     54  price for 1 night
# 142633       4.5 miles    Donauturm     Favoriten     54  price for 1 night
# 145275       6.3 miles    Donauturm    Schonbrunn     56  price for 1 night
# ...                ...          ...           ...    ...                ...
# 142915       3.0 miles    Donauturm  Innere Stadt    219  price for 1 night
# 143484       2.4 miles    Donauturm  Innere Stadt    223  price for 1 night
# 143339       2.7 miles    Donauturm  Innere Stadt    231  price for 1 night
# 143467       2.8 miles    Donauturm  Innere Stadt    242  price for 1 night
# 144499       4.7 miles    Donauturm    Margareten    383  price for 1 night
#
#         ...      offer_cat  year  month  weekend holiday nnights  acc_type  \
# 145548  ...   15-50% offer  2017     11        0       0       1     Hotel
# 145028  ...   15-50% offer  2017     11        0       0       1     Hotel
# 143663  ...   15-50% offer  2017     11        0       0       1     Hotel
# 142633  ...  50%-75% offer  2017     11        0       0       1     Hotel
# 145275  ...   15-50% offer  2017     11        0       0       1     Hotel
# ...     ...            ...   ...    ...      ...     ...     ...       ...
# 142915  ...    1-15% offer  2017     11        0       0       1     Hotel
# 143484  ...    0% no offer  2017     11        0       0       1     Hotel
# 143339  ...   15-50% offer  2017     11        0       0       1     Hotel
# 143467  ...    1-15% offer  2017     11        0       0       1     Hotel
# 144499  ...    0% no offer  2017     11        0       0       1     Hotel
#
#         ratings  distance distance_alter
# 145548      3.9       3.9            6.6
# 145028      3.5       3.1            5.2
# 143663      3.2       1.1            3.4
# 142633      3.5       2.0            4.5
# 145275      3.5       3.7            6.3
# ...         ...       ...            ...
# 142915      4.5       0.3            3.0
# 143484      3.5       0.5            2.4
# 143339      4.4       0.1            2.7
# 143467      4.8       0.0            2.8
# 144499      4.0       1.9            4.7
#
# [217 rows x 29 columns]

# %% [markdown]
# Or decreasing order

# %%
hotel_vienna.sort_values(by=["price"], ascending=False)
# Out:
#         country city_actual  rating_count center1distance center1label  \
# 144499  Austria      Vienna         122.0       1.9 miles  City centre
# 143467  Austria      Vienna         404.0       0.0 miles  City centre
# 143339  Austria      Vienna          56.0       0.1 miles  City centre
# 143484  Austria      Vienna         123.0       0.5 miles  City centre
# 142915  Austria      Vienna          81.0       0.3 miles  City centre
# ...         ...         ...           ...             ...          ...
# 145275  Austria      Vienna          79.0       3.7 miles  City centre
# 142633  Austria      Vienna         194.0       2.0 miles  City centre
# 143663  Austria      Vienna          63.0       1.1 miles  City centre
# 145028  Austria      Vienna          69.0       3.1 miles  City centre
# 145548  Austria      Vienna          50.0       3.9 miles  City centre
#
#        center2distance center2label neighbourhood  price        price_night  \
# 144499       4.7 miles    Donauturm    Margareten    383  price for 1 night
# 143467       2.8 miles    Donauturm  Innere Stadt    242  price for 1 night
# 143339       2.7 miles    Donauturm  Innere Stadt    231  price for 1 night
# 143484       2.4 miles    Donauturm  Innere Stadt    223  price for 1 night
# 142915       3.0 miles    Donauturm  Innere Stadt    219  price for 1 night
# ...                ...          ...           ...    ...                ...
# 145275       6.3 miles    Donauturm    Schonbrunn     56  price for 1 night
# 142633       4.5 miles    Donauturm     Favoriten     54  price for 1 night
# 143663       3.4 miles    Donauturm    Josefstadt     54  price for 1 night
# 145028       5.2 miles    Donauturm     Ottakring     52  price for 1 night
# 145548       6.6 miles    Donauturm        Vienna     50  price for 1 night
#
#         ...      offer_cat  year  month  weekend holiday nnights  acc_type  \
# 144499  ...    0% no offer  2017     11        0       0       1     Hotel
# 143467  ...    1-15% offer  2017     11        0       0       1     Hotel
# 143339  ...   15-50% offer  2017     11        0       0       1     Hotel
# 143484  ...    0% no offer  2017     11        0       0       1     Hotel
# 142915  ...    1-15% offer  2017     11        0       0       1     Hotel
# ...     ...            ...   ...    ...      ...     ...     ...       ...
# 145275  ...   15-50% offer  2017     11        0       0       1     Hotel
# 142633  ...  50%-75% offer  2017     11        0       0       1     Hotel
# 143663  ...   15-50% offer  2017     11        0       0       1     Hotel
# 145028  ...   15-50% offer  2017     11        0       0       1     Hotel
# 145548  ...   15-50% offer  2017     11        0       0       1     Hotel
#
#         ratings  distance distance_alter
# 144499      4.0       1.9            4.7
# 143467      4.8       0.0            2.8
# 143339      4.4       0.1            2.7
# 143484      3.5       0.5            2.4
# 142915      4.5       0.3            3.0
# ...         ...       ...            ...
# 145275      3.5       3.7            6.3
# 142633      3.5       2.0            4.5
# 143663      3.2       1.1            3.4
# 145028      3.5       3.1            5.2
# 145548      3.9       3.9            6.6
#
# [217 rows x 29 columns]

# %% [markdown]
# ### Task: writing out csv as clean data

# %%
hotel_vienna.to_csv("hotel_vienna_restricted.csv", index=False)
